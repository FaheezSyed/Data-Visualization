# %%
from pandas import DataFrame

data = [
["S001","Aisha Khan","CSE","Data Structures",92,78,85,88,8.4,"Good"],
["S002","Rahul Mehta","EEE","Circuit Theory",75,68,72,70,7.2,"Average"],
["S003","Divya Sharma","IT","DBMS",88,82,90,85,9.1,"Excellent"],
["S004","Sameer Ali","ME","Fluid Mechanics",60,55,58,50,6.0,"At Risk"],
["S005","Pooja Nair","CSE","Operating Systems",95,87,92,90,9.3,"Excellent"],
["S006","Arjun Reddy","ECE","Digital Electronics",72,65,69,60,7.0,"Average"],
["S007","Megha Patel","CIVIL","Structural Analysis",80,70,75,78,7.5,"Good"],
["S008","Farhan Syed","IT","Computer Networks",85,79,83,80,8.2,"Good"],
["S009","Neha Agarwal","BBA","Business Analytics",90,88,91,92,9.4,"Excellent"],
["S010","Vikram Singh","EEE","Signals & Systems",68,60,63,58,6.8,"Average"],
["S011","Sara Thomas","CSE","Machine Learning",94,89,93,91,9.5,"Excellent"],
["S012","Aditya Joshi","ME","Thermodynamics",62,58,61,55,6.2,"At Risk"],
["S013","Ananya Roy","IT","Web Technologies",88,80,85,82,8.7,"Good"],
["S014","Ritesh Kumar","ECE","Microprocessors",74,68,72,66,7.1,"Average"],
["S015","Preeti Menon","CIVIL","Environmental Engg",83,75,78,76,7.8,"Good"],
["S016","Harsh Verma","BBA","Marketing Management",91,85,88,90,9.0,"Excellent"],
["S017","Soniya Gupta","CSE","Algorithms",96,90,94,93,9.6,"Excellent"],
["S018","Rahman Ali","EEE","Power Systems",69,62,65,60,6.9,"Average"],
["S019","Nisha Kaur","IT","AI & Robotics",87,82,86,84,8.5,"Good"],
["S020","Deepak Sinha","ME","Manufacturing Tech",65,59,62,57,6.4,"At Risk"],
["S021","Vinay Patil","ECE","Embedded Systems",78,72,76,75,7.6,"Good"],
["S022","Shalini Rao","CSE","Cloud Computing",93,88,91,90,9.3,"Excellent"],
["S023","Anwar Hussain","CIVIL","Transportation Engg",70,63,67,65,6.8,"Average"],
["S024","Fatima Begum","BBA","Financial Accounting",89,83,87,85,8.8,"Good"],
["S025","Rajeev Kumar","EEE","Control Systems",76,69,72,70,7.3,"Average"],
["S026","Riya Sen","IT","Mobile App Dev",92,86,90,88,9.2,"Excellent"],
["S027","Sachin Desai","ME","Automotive Engg",61,55,58,52,6.1,"At Risk"],
["S028","Priyanka Jain","CSE","Cyber Security",90,84,88,87,8.9,"Good"],
["S029","Manoj Pillai","ECE","Signals Lab",73,66,70,65,7.0,"Average"],
["S030","Neeraj Yadav","CIVIL","Concrete Tech",82,74,77,76,7.7,"Good"],
["S031","Simran Kaur","BBA","HR Management",94,88,90,91,9.4,"Excellent"],
["S032","Rohit Sharma","IT","Big Data Analytics",89,83,86,85,8.8,"Good"],
["S033","Alisha Fernandes","CSE","AI Ethics",97,91,95,94,9.7,"Excellent"],
["S034","Kartik Rao","EEE","Electrical Machines",68,61,64,62,6.7,"Average"],
["S035","Zoya Ahmed","IT","Software Engineering",86,79,82,80,8.3,"Good"],
["S036","Aniket Kulkarni","ME","Robotics",64,58,60,56,6.3,"At Risk"],
["S037","Janvi Shukla","CIVIL","Geotechnical Engg",81,73,76,75,7.6,"Good"],
["S038","Dev Patel","ECE","Analog Circuits",75,68,71,70,7.2,"Average"],
["S039","Meera Iyer","BBA","Business Strategy",92,87,89,90,9.1,"Excellent"],
["S040","Kunal Singh","CSE","Blockchain Tech",95,90,94,93,9.5,"Excellent"],
["S041","Hari Krishnan","IT","IoT Systems",88,82,85,84,8.6,"Good"],
["S042","Pallavi Reddy","EEE","Signal Processing",72,65,68,67,7.0,"Average"],
["S043","Aravind Menon","ME","Heat Transfer",63,57,60,55,6.2,"At Risk"],
["S044","Disha Kapoor","CIVIL","Surveying",79,72,75,74,7.5,"Good"],
["S045","Mohammed Imran","BBA","Digital Marketing",90,85,88,89,9.0,"Excellent"],
["S046","Anjali Das","IT","Data Mining",87,80,83,82,8.4,"Good"],
["S047","Suresh Raina","CSE","Computer Vision",91,86,89,88,9.1,"Excellent"],
["S048","Leena George","ECE","VLSI Design",74,67,70,68,7.1,"Average"],
["S049","Arif Sheikh","CIVIL","Construction Planning",80,72,75,73,7.6,"Good"],
["S050","Nidhi Jain","BBA","Business Law",93,88,90,91,9.3,"Excellent"],
]

df = DataFrame(data, columns=["Student_ID","Name","Department","Course","Attendance_Percentage","Midterm_Score","Final_Score","Participation_Score","CGPA","Performance_Status"])
df.to_csv('university_dataset.csv', index=False)
print("✅ Full 50-row dataset saved at /mnt/data/university_dataset.csv")
# Out:
# ✅ Full 50-row dataset saved at /mnt/data/university_dataset.csv

# %%
import pandas as pd

df = pd.read_csv('university_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             50 non-null     object
#  1   Name                   50 non-null     object
#  2   Department             50 non-null     object
#  3   Course                 50 non-null     object
#  4   Attendance_Percentage  50 non-null     int64
#  5   Midterm_Score          50 non-null     int64
#  6   Final_Score            50 non-null     int64
#  7   Participation_Score    50 non-null     int64
#  8   CGPA                   50 non-null     float64
#  9   Performance_Status     50 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 4.0+ KB

# %%
df.head()
# Out:
#   Student_ID          Name Department             Course  \
# 0       S001    Aisha Khan        CSE    Data Structures
# 1       S002   Rahul Mehta        EEE     Circuit Theory
# 2       S003  Divya Sharma         IT               DBMS
# 3       S004    Sameer Ali         ME    Fluid Mechanics
# 4       S005    Pooja Nair        CSE  Operating Systems
#
#    Attendance_Percentage  Midterm_Score  Final_Score  Participation_Score  \
# 0                     92             78           85                   88
# 1                     75             68           72                   70
# 2                     88             82           90                   85
# 3                     60             55           58                   50
# 4                     95             87           92                   90
#
#    CGPA Performance_Status
# 0   8.4               Good
# 1   7.2            Average
# 2   9.1          Excellent
# 3   6.0            At Risk
# 4   9.3          Excellent

# %%
from PIL import Image, ImageDraw, ImageFont

# Create a simple flowchart-like image
img = Image.new("RGB", (900, 600), "white")
draw = ImageDraw.Draw(img)

font = ImageFont.load_default()

boxes = [
    ("Data Collection", 50, 50),
    ("Data Preprocessing", 350, 50),
    ("Data Integration", 650, 50),
    ("Visualization Prep", 200, 250),
    ("Dashboard Generation", 550, 250),
    ("Insights & Alerts", 350, 450),
]

for text, x, y in boxes:
    draw.rectangle([x, y, x+200, y+80], outline="black")
    draw.text((x+10, y+30), text, font=font, fill="black")

# Arrows
draw.line([250,90,350,90], fill="black", width=3)
draw.line([550,90,650,90], fill="black", width=3)
draw.line([450,130,300,250], fill="black", width=3)
draw.line([650,130,650,250], fill="black", width=3)
draw.line([450,330,450,450], fill="black", width=3)

img.show()

# %%
import pandas as pd

df = pd.read_csv('university_dataset.csv')

def highlight_with_icons(row):
    styles = []
    for col in row.index:
        if row['Performance_Status'] == 'At Risk':
            styles.append('background-color: red; color: white; font-weight: bold')
        elif row['Performance_Status'] == 'Excellent':
            styles.append('background-color: lightgreen; font-weight: bold')
        else:
            styles.append('')
    return styles

# Add icon column
df['Status_Icon'] = df['Performance_Status'].apply(lambda x: '⚠️' if x == 'At Risk' else '🏆' if x == 'Excellent' else '')

styled = df.style.apply(highlight_with_icons, axis=1)
styled
# Out:
# <style type="text/css">
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of CGPA
plt.figure(figsize=(8, 6))
sns.histplot(df['CGPA'], bins=10, kde=True)
plt.title('Distribution of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Frequency')
plt.show()

# Pie chart of department-wise student distribution
department_counts = df['Department'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Department-wise Student Distribution')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatterplot of attendance vs. grades (CGPA)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Attendance_Percentage', y='CGPA', data=df)
plt.title('Attendance Percentage vs. CGPA')
plt.xlabel('Attendance Percentage')
plt.ylabel('CGPA')
plt.show()

# Box plot of grades (CGPA) across departments
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='CGPA', data=df)
plt.title('CGPA Distribution Across Departments')
plt.xlabel('Department')
plt.ylabel('CGPA')
plt.xticks(rotation=45)
plt.show()

# %%
# Pair plot of grades across multiple courses
grade_columns = ['Attendance_Percentage', 'Midterm_Score', 'Final_Score', 'Participation_Score', 'CGPA']
sns.pairplot(df[grade_columns])
plt.suptitle('Pair Plot of Grade-Related Variables', y=1.02)
plt.show()

# %%
import plotly.express as px

# Create a treemap of students by department and course
fig = px.treemap(df, path=['Department', 'Course'],
                 title='Hierarchical Distribution of Students by Department and Course')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Task
# Construct a network graph showing collaboration or co-enrollment among students.

# %% [markdown]
# ## Define collaboration/co-enrollment
#
# ### Subtask:
# Determine how to define collaboration or co-enrollment based on the available data (e.g., students in the same department, students in the same course).

# %% [markdown]
# **Reasoning**:
# Analyze the DataFrame structure and content to determine a suitable definition for collaboration or co-enrollment.

# %%
import pandas as pd

df = pd.read_csv('university_dataset.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             50 non-null     object
#  1   Name                   50 non-null     object
#  2   Department             50 non-null     object
#  3   Course                 50 non-null     object
#  4   Attendance_Percentage  50 non-null     int64
#  5   Midterm_Score          50 non-null     int64
#  6   Final_Score            50 non-null     int64
#  7   Participation_Score    50 non-null     int64
#  8   CGPA                   50 non-null     float64
#  9   Performance_Status     50 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 4.0+ KB
#   Student_ID          Name Department             Course  \
# 0       S001    Aisha Khan        CSE    Data Structures
# 1       S002   Rahul Mehta        EEE     Circuit Theory
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an empty graph
G = nx.Graph()

# Add nodes for each student
for index, row in df.iterrows():
    G.add_node(row['Student_ID'], name=row['Name'], department=row['Department'])

# Add edges between students in the same department
for department in df['Department'].unique():
    department_students = df[df['Department'] == department]['Student_ID'].tolist()
    for i in range(len(department_students)):
        for j in range(i + 1, len(department_students)):
            G.add_edge(department_students[i], department_students[j])

# Draw the graph
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, k=0.5) # Layout for visualization
nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10, edge_color='gray')
plt.title('Network Graph of Students in the Same Department')
plt.show()

# %% [markdown]
# **Reasoning**:
# The DataFrame `df` was not found. Re-read the data from the CSV file as it was created in a previous cell.

# %%
# Generate sample course feedback, convert to TF-IDF vector space, and create a word cloud (neutral insight)
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample feedback (balanced mix)
feedback = [
    "The lectures were well structured and easy to follow.",
    "Too much theory, I prefer more practical examples.",
    "Professor explained difficult topics very clearly.",
    "The pace was slightly fast but overall informative.",
    "Assignments were challenging but helped understanding.",
    "Need more interactive sessions and real world applications.",
    "The teaching was engaging but sometimes rushed.",
    "Detailed explanations and good classroom environment.",
    "More doubt clearing sessions would be helpful.",
    "Great content but require more revision classes."
]

# a) Convert to vector space (TF-IDF)
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(feedback)

# b) Word cloud
text_data = " ".join(feedback)
wordcloud = WordCloud(width=800, height=400).generate(text_data)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Course Feedback (Neutral Insight)")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of Attendance Percentage
plt.figure(figsize=(8, 6))
sns.histplot(df['Attendance_Percentage'], bins=10, kde=True)
plt.title('Distribution of Attendance Percentage')
plt.xlabel('Attendance Percentage')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate the correlation coefficient between Attendance_Percentage and CGPA
correlation = df['Attendance_Percentage'].corr(df['CGPA'])

print(f"The correlation coefficient between Attendance_Percentage and CGPA is: {correlation:.2f}")
# Out:
# The correlation coefficient between Attendance_Percentage and CGPA is: 0.98

# %%
# Creating animated visualization of semester progression (CGPA trend)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter

# Load dataset
#df = pd.read_csv('/mnt/data/university_dataset.csv')

# Define semesters
semesters = ["Sem 1", "Sem 2", "Sem 3", "Sem 4"]

# Synthetic CGPA progression for animation
cgpa_matrix = np.stack([
    np.clip(df["CGPA"].values - 0.3 + np.random.randn(len(df))*0.05, 0, 10),
    np.clip(df["CGPA"].values - 0.1 + np.random.randn(len(df))*0.05, 0, 10),
    np.clip(df["CGPA"].values + 0.1 + np.random.randn(len(df))*0.05, 0, 10),
    np.clip(df["CGPA"].values + 0.2 + np.random.randn(len(df))*0.05, 0, 10),
], axis=1)
avg_cgpa_by_sem = cgpa_matrix.mean(axis=0)

# Convert semesters to numeric index for animation axis
x_idx = np.arange(len(semesters))

# Setup animation plot
fig, ax = plt.subplots()
ax.set_title("Semester Progression: Average CGPA (Animated)")
ax.set_xlabel("Semester")
ax.set_ylabel("Average CGPA")
ax.set_ylim(0, 10)
ax.set_xticks(x_idx)
ax.set_xticklabels(semesters)
line, = ax.plot([], [], marker='o')

def init():
    line.set_data([], [])
    return line,

def update(frame):
    x = x_idx[:frame+1]
    y = avg_cgpa_by_sem[:frame+1]
    line.set_data(x, y)
    return line,

ani = FuncAnimation(fig, update, frames=len(semesters), init_func=init, blit=True, repeat=False)

# Save animation
file_path = "animated_semester_progression.gif"
ani.save(file_path, writer=PillowWriter(fps=1))

print(f"✅ Animated visualization saved as: {file_path}")
# Out:
# ✅ Animated visualization saved as: animated_semester_progression.gif

# %%
# Force-based Layout Visualization using NetworkX
import networkx as nx
import matplotlib.pyplot as plt
# ---- Step 1: Create sample dataset (edges) ----
edges = [
("Alice", "Bob"),
("Alice", "Cathy"),
("Alice", "David"),
("Bob", "Eve"),
("Cathy", "Frank"),
("David", "Grace"),
("Eve", "Helen"),
("Frank", "Grace"),
("Helen", "Ivy"),
("Grace", "Jack"),
("Ivy", "Jack")
]
# ---- Step 2: Create a Graph ----
G = nx.Graph()
G.add_edges_from(edges)
# ---- Step 3: Compute Force-based Layout ----
# spring_layout uses the Fruchterman-Reingold algorithm
pos = nx.spring_layout(G, seed=42)
# ---- Step 4: Visualize the Graph ----
plt.figure(figsize=(8,6))
nx.draw(G, pos, with_labels=True,
node_color='lightblue',
node_size=1200,
font_size=10,
font_weight='bold',
edge_color='gray')
plt.title("Force-based Layout Visualization", fontsize=14)
plt.show()
